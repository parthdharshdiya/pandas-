# %%
import pandas as pd;
df = pd.read_csv("Airbnb_Open_Data.csv");
# print(df.tail(5));
# print(df.head(5))
# print(df);
# print(df['license'])
print(df.info())
# Out:
# C:\Users\PARTH\AppData\Local\Temp\ipykernel_24052\4149488092.py:2: DtypeWarning: Columns (0: license) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Airbnb_Open_Data.csv");
# <class 'pandas.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  str
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  str
#  4   host name                       102193 non-null  str
#  5   neighbourhood group             102570 non-null  str
#  6   neighbourhood                   102583 non-null  str
#  7   lat                             102591 non-null  float64
# ...

# %%
df['license'];
# print(df);
print(df.columns);
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='str')

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review',];
columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license'];

# %%
len(columns_to_keep);

# %%
len(columns_to_drop);

# %%
df[columns_to_keep];

# %%
df[columns_to_drop];

# %%
df.shape
# Out:
# (102599, 26)

# %% [markdown]
# 2nd method dropping columns

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %% [markdown]
# 2 Method Dropping COlumns

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules'],
#       dtype='str')

# %%
df.drop(columns=columns_to_drop,inplace=True);

# %%
df.shape
# Out:
# (102599, 25)

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules'],
#       dtype='str')

# %%
df.rename(columns={"NAME":"Name"},inplace=True);
print(df)
# Out:
#              id                                              Name  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
print(df.columns);
# Out:
# Index(['id', 'Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules'],
#       dtype='str')

# %%
new_columns = [];
for i in df.columns:
     new_columns.append(i.upper());
print(new_columns)
# Out:
# ['ID', 'NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME', 'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY', 'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE', 'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS', 'NUMBER OF REVIEWS', 'LAST REVIEW', 'REVIEWS PER MONTH', 'REVIEW RATE NUMBER', 'CALCULATED HOST LISTINGS COUNT', 'AVAILABILITY 365', 'HOUSE_RULES']

# %%
df.duplicated().sum();

# %%
New_DataFrame_Modify =  df.copy();
# Out:
#              id                                              Name  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
New_DataFrame_Modify.columns
# Out:
# Index(['id', 'Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules'],
#       dtype='str')

# %%
New_DataFrame_Modify.columns = new_columns;

# %%
New_DataFrame_Modify
# Out:
#              id                                              Name  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True);

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
"""
  Deleting redundant columns
  Renaming the columns
  dropping duplicates
  cleaning indivisual columns
  Remove nan value from dataset
  check for some more Transformations
"""

# %%
df.isna().sum();

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# id                                0
# Name                              0
# host id                           0
# host_identity_verified            0
# host name                         0
# neighbourhood group               0
# neighbourhood                     0
# lat                               0
# long                              0
# country                           0
# country code                      0
# instant_bookable                  0
# cancellation_policy               0
# room type                         0
# Construction year                 0
# price                             0
# service fee                       0
# minimum nights                    0
# number of reviews                 0
# reviews per month                 0
# review rate number                0
# calculated host listings count    0
# availability 365                  0
# house_rules                       0
# dtype: int64

# %%
df
# Out:
#               id                                               Name  \
# 0        1001254                 Clean & quiet apt home by the park
# 1        1002102                              Skylit Midtown Castle
# 4        1003689   Entire Apt: Spacious Studio/Loft by central park
# 5        1004098          Large Cozy 1 BR Apartment In Midtown East
# 7        1005202                                    BlissArtsSpace!
# ...          ...                                                ...
# 102025  57349744       COZY Large Private APARTMENT in EAST VILLAGE
# 102028  57351400  Gorgeous condo 20min from NYC,close to the air...
# 102029  57351953             Cozy room in a 2B with backyard access
# 102031  57353057                       Cozy bedroom in williamsburg
# 102040  57358028                      Room in Queens, NY, near LGA.
#
#             host id host_identity_verified host name neighbourhood group  \
# 0       80014485718            unconfirmed  Madaline            Brooklyn
# ...

# %%
df["host_identity_verified"].str.upper();

# %%
df['host_identity_verified'] = df["host_identity_verified"].str.upper();
# Out:
#               id                                               Name  \
# 0        1001254                 Clean & quiet apt home by the park
# 1        1002102                              Skylit Midtown Castle
# 4        1003689   Entire Apt: Spacious Studio/Loft by central park
# 5        1004098          Large Cozy 1 BR Apartment In Midtown East
# 7        1005202                                    BlissArtsSpace!
# ...          ...                                                ...
# 102025  57349744       COZY Large Private APARTMENT in EAST VILLAGE
# 102028  57351400  Gorgeous condo 20min from NYC,close to the air...
# 102029  57351953             Cozy room in a 2B with backyard access
# 102031  57353057                       Cozy bedroom in williamsburg
# 102040  57358028                      Room in Queens, NY, near LGA.
#
#             host id host_identity_verified host name neighbourhood group  \
# 0       80014485718            UNCONFIRMED  Madaline            Brooklyn
# ...

# %%
df
# Out:
#               id                                               Name  \
# 0        1001254                 Clean & quiet apt home by the park
# 1        1002102                              Skylit Midtown Castle
# 4        1003689   Entire Apt: Spacious Studio/Loft by central park
# 5        1004098          Large Cozy 1 BR Apartment In Midtown East
# 7        1005202                                    BlissArtsSpace!
# ...          ...                                                ...
# 102025  57349744       COZY Large Private APARTMENT in EAST VILLAGE
# 102028  57351400  Gorgeous condo 20min from NYC,close to the air...
# 102029  57351953             Cozy room in a 2B with backyard access
# 102031  57353057                       Cozy bedroom in williamsburg
# 102040  57358028                      Room in Queens, NY, near LGA.
#
#             host id host_identity_verified host name neighbourhood group  \
# 0       80014485718            UNCONFIRMED  Madaline            Brooklyn
# ...

# %%
df["instant_bookable"].apply(lambda x:1 if x == True else 0);

# %%
df = df["instant_bookable"].apply(lambda x:1 if x == True else 0);

# %%
df.reset_index()
# Out:
#         index        id                                               Name  \
# 0           0   1001254                 Clean & quiet apt home by the park
# 1           1   1002102                              Skylit Midtown Castle
# 2           4   1003689   Entire Apt: Spacious Studio/Loft by central park
# 3           5   1004098          Large Cozy 1 BR Apartment In Midtown East
# 4           7   1005202                                    BlissArtsSpace!
# ...       ...       ...                                                ...
# 39415  102025  57349744       COZY Large Private APARTMENT in EAST VILLAGE
# 39416  102028  57351400  Gorgeous condo 20min from NYC,close to the air...
# 39417  102029  57351953             Cozy room in a 2B with backyard access
# 39418  102031  57353057                       Cozy bedroom in williamsburg
# 39419  102040  57358028                      Room in Queens, NY, near LGA.
#
# ...
